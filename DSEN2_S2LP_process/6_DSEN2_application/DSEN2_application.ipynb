# %% [markdown]
# # Imports

# %%
import os
import zipfile, os

import shutil
import glob
import os

# %% [markdown]
# # Directory Function

# %%
def directory1(directory):
    """Gets the names of a directory"""
    entries = os.listdir(directory)
    return entries
    # print(entries)

# %%
directory1("C:/Users/nkalimip/Downloads/DSEN2_process/Images_unzipped")
# Out:
# ['S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006',
#  'S2A_MSIL2A_20190606T165901_N0212_R069_T15TYM_20190606T212006',
#  'S2A_MSIL2A_20190606T165901_N0212_R069_T16TCS_20190606T212006',
#  'S2A_MSIL2A_20200713T170901_N0214_R112_T14SQJ_20200713T213310',
#  'S2A_MSIL2A_20200713T170901_N0214_R112_T15STD_20200713T213310',
#  'S2A_MSIL2A_20200806T164901_N0214_R026_T15TYM_20200806T211742',
#  'S2A_MSIL2A_20200806T164901_N0214_R026_T16TCS_20200806T211742',
#  'S2A_MSIL2A_20210724T190921_N0301_R056_T10TER_20210724T233407',
#  'S2A_MSIL2A_20210826T173911_N0301_R098_T13SCS_20210826T234856',
#  'S2B_MSIL2A_20190608T164849_N0212_R026_T15TYL_20190608T212115',
#  'S2B_MSIL2A_20190822T173909_N0213_R098_T13SCS_20190822T220238',
#  'S2B_MSIL2A_20190825T174909_N0213_R141_T13SCS_20190825T214149',
#  'S2B_MSIL2A_20190826T153819_N0213_R011_T18TYN_20190826T195901',
#  'S2B_MSIL2A_20200627T173909_N0214_R098_T13TGM_20200627T213600',
# ...

# %% [markdown]
# # Unzipping Function

# %%
def unzipping_function(directory):
    """unzip the files in the directory"""
    working_directory = directory
    os.chdir(working_directory)

    for file in os.listdir(working_directory):   # get the list of files
        if zipfile.is_zipfile(file): # if it is a zipfile, extract it
            with zipfile.ZipFile(file) as item: # treat the file as a zip
               item.extractall()  # extract it in the working directory

# %%
unzipping_function('C:/Users/nkalimip/Downloads/test1')

# %% [markdown]
# # Moving zipped file function

# %%
def moving_zip_files(source, dest):
    """Moving zip files to another location"""
    source = source
    mydict = {
        dest: ['zip'],
        #'/home/xxx/Documents': ['doc','docx','pdf','xls']
    }

    for destination, extensions in mydict.items():
        for ext in extensions:
            for file in glob.glob(source + '*.' + ext):
                print(file)
                shutil.move(file, destination)

# %%
moving_zip_files('C:/Users/nkalimip/Downloads/test1/','C:/Users/nkalimip/Downloads/test1zip/')

# %% [markdown]
# # Running DSEN2

# %% [markdown]
# ## Imports (for all Methods)

# %%
#apply dsen2 for all images in the directory
    # extract the pixel coordinates from geometry
    # output directory
    #select if copy bands

# %%
# %cd C:\Users\nkalimip\Downloads\DSen2-master\DSen2-master\testing
# Out:
# C:\Users\nkalimip\Downloads\DSen2-master\DSen2-master\testing

# %%
# %matplotlib inline

# %%
from osgeo import gdal, osr
import tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.10.1
# Num GPUs Available:  1

# %% [markdown]
# ## Method 1: Typical Ipython method (working)

# %%
# %run s2_tiles_supres.py C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml C:/Users/nkalimip/Downloads/output_file1c.tif --roi_x_y "100,100,2000,2000"
# Out:
# SENTINEL2_L1C:C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml:10m:EPSG_32610
# SENTINEL2_L1C:C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml:20m:EPSG_32610
# SENTINEL2_L1C:C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml:60m:EPSG_32610
# SENTINEL2_L1C:C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml:TCI:EPSG_32610
# Selected UTM Zone: UTM 10N
# Selected pixel region: xmin=96, ymin=96, xmax=1997, ymax=1997:
# Image size: width=1902 x height=1902
# Selected 10m bands: B4 B3 B2 B8
# ...

# %% [markdown]
# ## Method 2: Pass string to cmd inside python (not working yet)

# %%
import os 
from subprocess import check_output

# check_output('dir C:', shell=True)

# check_output("cd C:", shell=True)
# check_output('cd C:/Users/nkalimip/Downloads/DSen2-master/DSen2-master/testing', shell=True)
# check_output("python s2_tiles_supres.py C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml C:/Users/nkalimip/Downloads/output_file1c.tif --roi_x_ y '100,100,2000,2000'", shell=True)

# python s2_tiles_supres.py C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml C:/Users/nkalimip/Downloads/output_file1c.tif --roi_x_ y "100,100,2000,2000"
# check_output("python", shell=True)
# Out:
# b''

# %% [markdown]
# ## Method 3: Pass string to run (working)

# %% [markdown]
# ### Simplified

# %%
name = 's2_tiles_supres.py C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml C:/Users/nkalimip/Downloads/output_file1c.tif --roi_x_y "100,100,2000,2000"'
# name = 's2_tiles_supres.py  C:/Users/nkalimip/Downloads/DSEN2_process/Images_unzipped/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006.SAFE/MTD_MSIL2A.xml C:/Us/ers/nkalimip/Downloads/DSEN2_process/newS2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006.tif --roi_x_y "6460,4883,6800,6385"'

# name = 's2_tiles_supres.py  C:/Users/nkalimip/Downloads/DSEN2_process/Images_unzipped/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006.SAFE/MTD_MSIL2A.xml C:/Users/nkalimip/Downloads/DSEN2_process/new1/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006.tif --roi_x_y "6460,4883,6800,6385" '

# %run $name
# Out:
# SENTINEL2_L1C:C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml:10m:EPSG_32610
# SENTINEL2_L1C:C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml:20m:EPSG_32610
# SENTINEL2_L1C:C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml:60m:EPSG_32610
# SENTINEL2_L1C:C:/Users/nkalimip/Downloads/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239/S2B_MSIL1C_20220731T185919_N0400_R013_T10TES_20220731T211239.SAFE/MTD_MSIL1C.xml:TCI:EPSG_32610
# Selected UTM Zone: UTM 10N
# Selected pixel region: xmin=96, ymin=96, xmax=1997, ymax=1997:
# Image size: width=1902 x height=1902
# Selected 10m bands: B4 B3 B2 B8
# ...

# %% [markdown]
# ### Actual

# %%
def ipython_command_maker(file_list,pixel_list, input_directory,output_directory,include_original_bands):
    """Method 2: pass string to %run"""
    s2_tiles_supres_name = "s2_tiles_supres.py "
    
    # pixel_name =  '--roi_x_y '+  f'"{pixel_info}"'
    # print(pixel_name)
    directory_arr = file_list
    for counter in range(0,len(directory_arr)):
        image_name = directory_arr[counter]
        
        image_name_list=image_name.split("_")
        level_name_full = image_name_list[1]  
        
        pixel_name =   '--roi_x_y '+  f'"{pixel_list[counter]}"'
        
        input_file_name = input_directory+image_name+"/"+image_name+".SAFE/MTD_"+level_name_full+ ".xml"
        output_file_name = output_directory+image_name+ ".tif"
        if include_original_bands ==1:
            outputfile = s2_tiles_supres_name+" "+ input_file_name+" "+ output_file_name+ " "+ pixel_name+ " --copy_original_bands"
        else:
            outputfile = s2_tiles_supres_name+" "+ input_file_name+" "+ output_file_name+ " "+ pixel_name

        # print(outputfile)
        
        # %run $outputfile

# %%
# pixel_list = ["6460,4883,6800,6385","6384,6765,6823,8292","201,7062,586,8827","1988,8137,2253,8900","79,7882,220,8651","6529,6796,6840,8422",\
# "240,7129,504,8762","5094,2632,5335,3861","2540,7945,2809,9918","6467,4883,6804,6365","2521,7857,2810,9990","2488,7893,2841,9998",\
#  "1826,8923,2067,9652","10943,423,10944,424","5316,1077,5485,2346" , "8895,8394,9160,9663","5600,8553,5817,9841","8873,7145,9125,8478",\
#  "10935,475,10936,478","5272,1069,5509,2350","5054,2598,5399,3935","7968,1541,8265,3074","5060,2609,5337,3894" ,"6322,8801,6545,9985",\
#  "2490,7897,2833,9943" ,"2490,7897,2833,9943"]
  
    
    
pixel_list = ["6460,4883,6800,6385","6384,6765,6823,8292","201,7062,586,8827","1988,8137,2253,8900","79,7882,220,8651","6529,6796,6840,8422",\
"240,7129,504,8762","5094,2632,5335,3861","2540,7945,2809,9918","6467,4883,6804,6365","2521,7857,2810,9990","2488,7893,2841,9998",\
 "1826,8923,2067,9652","10943,423,10944,424","5316,1077,5485,2346" , "8895,8394,9160,9663","5600,8553,5817,9841","8873,7145,9125,8478",\
 "10935,475,10936,478","5272,1069,5509,2350","5054,2598,5399,3935","5060,2609,5337,3894" ,"6322,8801,6545,9985",\
 "2490,7897,2833,9943"]

file_list = directory1("C:/Users/nkalimip/Downloads/DSEN2_process/Images_unzipped")

# file_list = ['S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006']
#import panda as
# d = {"Pixel list": pixel_list, "file_list": file_list}
# df = pd.DataFrame(d)


# ipython_command_maker(file_list, pixel_list,"C:/Users/nkalimip/Downloads/DSEN2_process/Images_unzipped/","C:/Users/nkalimip/Downloads/DSEN2_process/new/",0)
ipython_command_maker(file_list, pixel_list,"C:/Users/nkalimip/Downloads/DSEN2_process/Images_unzipped/","C:/Users/nkalimip/Downloads/new1/",1)
# Out:
# SENTINEL2_L2A:C:/Users/nkalimip/Downloads/DSEN2_process/Images_unzipped/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006.SAFE/MTD_MSIL2A.xml:10m:EPSG_32615
# SENTINEL2_L2A:C:/Users/nkalimip/Downloads/DSEN2_process/Images_unzipped/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006.SAFE/MTD_MSIL2A.xml:20m:EPSG_32615
# SENTINEL2_L2A:C:/Users/nkalimip/Downloads/DSEN2_process/Images_unzipped/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006.SAFE/MTD_MSIL2A.xml:60m:EPSG_32615
# SENTINEL2_L2A:C:/Users/nkalimip/Downloads/DSEN2_process/Images_unzipped/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006/S2A_MSIL2A_20190606T165901_N0212_R069_T15TYL_20190606T212006.SAFE/MTD_MSIL2A.xml:TCI:EPSG_32615
# Selected UTM Zone: UTM 15N
# ...

# %%
# export tasks to Earth Engine
# export_task_10m = ee_func.export_collection_to_gee(collection=export_collection_10m,
#                                                    num_images=1,
#                                                    # image_names=[siteSelect+'_'+outputName+'_SL2P10'],
#                                                    image_names = image_output_names_10m,
#                                                    scale=10,
#                                                    # asset_folder='users/kateharvey/SL2P10_images',
#                                                    asset_folder=assetfolder,
#                                                    # data_type=exportDataType,
#                                                    data_type='float',
#                                                    max_pixels=1e13)
